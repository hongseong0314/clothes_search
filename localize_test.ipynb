# %%
from codes.detection import Img_localize
import os
import cv2
import matplotlib.pyplot as plt
import time

# %%
# test img 1 cluster 방식
path = os.path.join(os.getcwd(), 'img/test1.png')
st = time.time()
imgs = Img_localize(path, 2)
print("function time(s) {0:.3f}".format(time.time()-st))
for img in imgs:
    plt.imshow(img)
    plt.show()
# Out:
# function time(s) 1.043

# %%
# test img 2 claster 방식
path = os.path.join(os.getcwd(), 'img/test2.png')
st = time.time()
imgs = Img_localize(path, 2)
print("function time(s) {0:.3f}".format(time.time()-st))
for img in imgs:
    plt.imshow(img)
    plt.show()
# Out:
# function time(s) 0.068

# %%
# test img 1 absorption 방식
path = os.path.join(os.getcwd(), 'img/test1.png')
st = time.time()
imgs = Img_localize(path, 2, "absorption")
print("function time(s) {0:.3f}".format(time.time()-st))
for img in imgs:
    plt.imshow(img)
    plt.show()
# Out:
# function time(s) 0.077

# %%
# test img 2 absorption 방식
path = os.path.join(os.getcwd(), 'img/test2.png')
st = time.time()
imgs = Img_localize(path, 2, "absorption")
print("function time(s) {0:.3f}".format(time.time()-st))
for img in imgs:
    plt.imshow(img)
    plt.show()
# Out:
# function time(s) 0.114
